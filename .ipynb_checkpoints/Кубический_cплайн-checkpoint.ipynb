# %% [markdown]
# ## Кубические сплайны

# %% [markdown]
# $\textbf{Кубический сплайн}$ (дефекта 1), интерполирующий $f(x)$ на $[a, b]$: $$c(x) := d_k + c_k (x-x_k) + b_k (x-x_k)^2 + a_k (x-x_k)^3,$$
#
# где $x\in [x_{k-1}, x_{k}] \big|_{k=1}^n$
#
# $\textbf{Обозначение кубического сплайна дефекта 1}$: $S^n_{3,2}$, где $n, 3, 2$ - кол-во узлов интерполирования, старшая степень и порядок гладкости сплайна соответственно.
#
# $\textbf{Краевые условия}$:
# $$ \textbf{1)}\; c(x_k) = f(x_k), \;\; \textbf{2)}\; c(x) \in C^2([a,b]), \;\; \textbf{3)}\; c''(a) = c''(b)=0$$
# При выполнении условия $\textbf{3)}$ сплайн называется $\textbf{естественным}$.

# %%
import numpy as np
import matplotlib.pyplot as plt 
np.set_printoptions(suppress=True)

# %%
# Матрица в виде AB = C  
# Исходная функция
def fn(x):
    return x**2 + 4*np.sin(x) - 2

# %%
# a = float(input('Введите левую границу a: '))
# b = float(input('Введите правую границу b: '))
# m = int(input('Введите кол-во равноотстоящих узлов m (целое число): '))

# %% [markdown]
# ## Кубические сплайны по равноотстоящим узлам

# %%
def cub_spline(arg, a, b, m, fig=None):
    x = np.linspace(a, b, m)
    # m - число узлов
    n = m - 1
    # n - число кубических сплайнов

    A = np.zeros((4*n, 4*n))
    C = np.zeros(4*n)

    for i in range(n):
        A[i, i] = x[i]**3
        A[i, n+i] = x[i]**2
        A[i, 2*n+i] = x[i]
        A[i, 3*n+i] = 1

        # Строки [n, 2n-1]
        A[n+i, i] = x[i+1]**3
        A[n+i, n+i] = x[i+1]**2
        A[n+i, 2*n+i] = x[i+1]
        A[n+i, 3*n+i] = 1

        C[i] = fn(x[i])
        C[n+i] = fn(x[i+1])

    # Строки [2n, 3n-1]
    for j in range(n-1):
        row = 2*n+j
        columns = [j, j+1, n+j, n+j+1, 2*n+j, 2*n+j+1]
        #start at j+1 since derivatives are equal at the interior points
        values = 3*x[j+1]**2, -3*x[j+1]**2, 2*x[j+1], -2*x[j+1], 1, -1
        A[row, [columns]] = values

        # Значения функции для рядов C из промежутка [2n: 3n-1] равны нулю, поскольку мы приравниваем произвдоные

    # Строки [3n-1, 4n-2]
    for q in range(n-1):
        row = 3*n-1 + q
        columns = [q, q+1, n+q, n+q+1]
        values = 6*x[q+1], -6*x[q+1], 2, -2
        A[row, [columns]] = values
        # Значения функции для рядов C из промежутка [3n-1: 4n-2] равны нулю, поскольку мы приравниваем произвдоные

    # Задаем вторые производные на граничны точках (x0, xn) равными нулю, 
    # чтобы получить два дополнительных уравнения - естественный сплайн
    A[4*n-2, [0,n]] = 6*x[0], 2
    A[4*n-1, [n-1,2*n-1]] =  6*x[n], 2

    # Решаем относительно b
    B = np.linalg.solve(A,C)

    ai = B[:n]
    bi = B[n:2*n]
    ci = B[2*n:3*n]
    di = B[3*n:]
    
    # Вычисление значения от кубического сплайна     
    if fig == None:
        flag = 0
        res = 0
        eps = 10**(-6)
        for i in range(n):
            if arg == a:
                arg += eps
                flag = i
                res = ai[flag]*arg**3 + bi[flag]*arg**2 + ci[flag]*arg + di[flag]
            elif arg == b:
                arg -= eps
                flag = i
                res = ai[flag]*arg**3 + bi[flag]*arg**2 + ci[flag]*arg + di[flag]
            elif (arg > x[i]) and (arg < x[i+1]):
                flag = i
                res = ai[flag]*arg**3 + bi[flag]*arg**2 + ci[flag]*arg + di[flag]
        return res

    # Изображение на графике     
    elif fig == True:
        plt.figure()
        for k in range(n):
            xspline = np.linspace(x[k], x[k+1])
            yspline = ai[k]*xspline**3 + bi[k]*xspline**2 + ci[k]*xspline + di[k]    
            plt.plot(xspline, yspline, '-', linewidth=4)

        plt.xlabel('x')
        plt.ylabel('y')
        plt.title('$S_{3,2}^m$ по равноотстоящим узлам для $f(x)$')
        plt.show()

# %%
cub_spline(arg=5, a=-4, b=10, m=100)
# Out:
# 19.16430632648178

# %% [markdown]
# ## Изобразим $S_{3,2}^m$ по равноотстоящим узлам

# %%
cub_spline(arg=5, a=-4, b=10, m=100, fig=True)

# %% [markdown]
# ## Кубические сплайны по оптимальным узлам Чебышева $$x_i = 0.5 \left((b-a)\cos\dfrac{(2i+1)\pi}{2(n+1)} + (b+a)\right),\; i\in \overline{0,n}$$

# %%
# m - число узлов
# n - число кубических сплайнов
# n сплайнов, у каждого 3 неизвестных, итого 3*n неизвестных
# Значит, нужно решить 3*n уравнений

def optimal_cub_spline(arg, a, b, m, fig=None):
    chebish = []
    n = m - 1
    for i in range(0, m):
        chebish.append(0.5 * ((b-a)*np.cos(((2*i+1)*np.pi)/(2*(m+1))) + (b+a)))

    A_opt = np.zeros((4*n, 4*n))*1.0
    C_opt = np.zeros(4*n)*1.0

    for i in range(n):
        A_opt[i, i] = chebish[i]**3
        A_opt[i, n+i] = chebish[i]**2
        A_opt[i, 2*n+i] = chebish[i]
        A_opt[i, 3*n+i] = 1

        # Строки [n, 2n-1]
        A_opt[n+i, i] = chebish[i+1]**3
        A_opt[n+i, n+i] = chebish[i+1]**2
        A_opt[n+i, 2*n+i] = chebish[i+1]
        A_opt[n+i, 3*n+i] = 1

        C_opt[i] = fn(chebish[i])
        C_opt[n+i] = fn(chebish[i+1])

    # Строки [2n, 3n-1]
    for j in range(n-1):
        row = 2*n+j
        columns = [j, j+1, n+j, n+j+1, 2*n+j, 2*n+j+1]
        # start at j+1 since derivatives are equal at the interior points
        values = 3*chebish[j+1]**2, -3*chebish[j+1]**2, 2*chebish[j+1], -2*chebish[j+1], 1, -1
        A_opt[row, [columns]] = values

        # Значения функции для рядов C из промежутка [2n: 3n-1] равны нулю, поскольку мы приравниваем произвдоные

        # Строки [3n-1, 4n-2]
    for q in range(n-1):
        row = 3*n-1 + q
        columns = [q, q+1, n+q, n+q+1]
        values = 6*chebish[q+1], -6*chebish[q+1], 2, -2
        A_opt[row, [columns]] = values
        # Значения функции для рядов C из промежутка [3n-1: 4n-2] равны нулю, поскольку мы приравниваем произвдоные

    # Задаем вторые производные на граничны точках (x0, xn) равными нулю, 
    # чтобы получить два дополнительных уравнения - естественный сплайн
    A_opt[4*n-2, [0,n]] = 6*chebish[0], 2
    A_opt[4*n-1, [n-1,2*n-1]] =  6*chebish[n], 2

    # Решаем относительно b
    B_opt = np.linalg.solve(A_opt, C_opt)

    ai_opt = B_opt[:n]
    bi_opt = B_opt[n:2*n]
    ci_opt = B_opt[2*n:3*n]
    di_opt = B_opt[3*n:]
    
    # Вычисление значения от кубического сплайна     
    flag = 0
    res = 0
    eps = 10**(-6)

    if fig == None:
        for i in range(n):
            if arg == a:
                arg -= eps
                flag = i
                res = ai_opt[flag]*arg**3 + bi_opt[flag]*arg**2 + ci_opt[flag]*arg + di_opt[flag]
            elif arg == b:
                arg += eps
                flag = i
                res = ai_opt[flag]*arg**3 + bi_opt[flag]*arg**2 + ci_opt[flag]*arg + di_opt[flag]
            elif (arg < chebish[i]) and (arg > chebish[i+1]):
                flag = i
                res = ai_opt[flag]*arg**3 + bi_opt[flag]*arg**2 + ci_opt[flag]*arg + di_opt[flag]
        return res

    # Изображение на графике     
    elif fig == True:
        plt.figure()
        for k in range(n):
            xspline = np.linspace(chebish[k], chebish[k+1])
            yspline = ai_opt[k]*xspline**3 + bi_opt[k]*xspline**2 + ci_opt[k]*xspline + di_opt[k]    
            plt.plot(xspline, yspline, '-', linewidth=4)

        plt.xlabel('x')
        plt.ylabel('y')
        plt.title('$S_{3,2}^m$ по равноотстоящим узлам для $f(x)$')
        plt.show()

# %%
optimal_cub_spline(arg=10, a=-10, b=10, m=10, fig=None)
# Out:
# 95.70489443965275

# %% [markdown]
# ## Изобразим  $S^m_{3,2}$ по оптимальным узлам Чебышева

# %%
optimal_cub_spline(arg=5, a=-10, b=10, m=10, fig=True)

# %% [markdown]
# ## Найдем максимальные отклонения $RS_{3,2}^n, RS_{3,2}^{n_{opt}}$

# %%
k = int(input('Введите количество k точек разбиения интервала интерполирования, в которых определяются отклонения: '))
max_nodes = int(input('Введите максимальное количество max_nodes узлов: '))
# mds = maximum_difference_segment
mds = np.linspace(a, b, k)

func_mds = []
spline_mds = []
optimal_spline_mds = []
RSn_mp = []
RSn_opt_mp = []

# значения точной функции в точках x0, x1, ..., xm; m >> n
for i in mds:
    func_mds.append(fn(i))

print('Таблица 1:')
print('-----------------------------------------------------------------------------------------------------------')
print('| кол-во узлов, n | кол-во точек разбиения, k   | max RSn_mp \t\t | max RSn_opt_mp \t\t|' )
print('-----------------------------------------------------------------------------------------------------------')

for pp in range(3, max_nodes + 1):
    # Ищем отклонения     
    for p in mds:
        # значения линейного сплайна S_{3,2}^n в точках x0, x1, ..., xk; k >> n  
        spline_mds.append(cub_spline(arg=p, a=-10, b=10, m=pp, fig=None))
        # значения линейного сплайна S_{3,2}^{n_opt} в точках x0, x1, ..., xk; k >> n        
        optimal_spline_mds.append(optimal_cub_spline(arg=p, a=-10, b=10, m=pp, fig=None))    
    # Отклонения
    for j in range(1, len(mds)):
        RSn_mp.append(np.absolute(func_mds[j] - spline_mds[j]))
        RSn_opt_mp.append(np.absolute(func_mds[j] - optimal_spline_mds[j]))
    RSn_mp_max = max(RSn_mp)
    RSn_opt_mp_max = max(RSn_opt_mp)
    
    print('|\t', pp, '\t|\t\t', k, '\t  |', RSn_mp_max, '\t|', RSn_opt_mp_max, '\t\t |')
    print('-----------------------------------------------------------------------------------------------------------')
    RSn_mp = []
    RSn_opt_mp = []
    RSn_mp_max, RSn_opt_mp_max = 0, 0
    spline_mds = []
    optimal_spline_mds = []
# Out:
# Введите количество k точек разбиения интервала интерполирования, в которых определяются отклонения: 50
# Введите максимальное количество max_nodes узлов: 150
# Таблица 1:
# -----------------------------------------------------------------------------------------------------------
# | кол-во узлов, n | кол-во точек разбиения, k   | max RSn_mp 		 | max RSn_opt_mp 		|
# -----------------------------------------------------------------------------------------------------------
# |	 3 	|		 50 	  | 12.442779403824701 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 4 	|		 50 	  | 10.239735996337593 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 5 	|		 50 	  | 9.693221920688494 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 6 	|		 50 	  | 7.863012503567965 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 7 	|		 50 	  | 4.798543924369859 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 8 	|		 50 	  | 52.05092182483618 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 9 	|		 50 	  | 1.2390681285357168 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 10 	|		 50 	  | 0.8649620013405723 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 11 	|		 50 	  | 0.7897708732679831 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 12 	|		 50 	  | 0.677694597096135 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 13 	|		 50 	  | 0.5654884812496874 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 14 	|		 50 	  | 0.46950846956977443 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 15 	|		 50 	  | 52.05092182483618 	| 90.66846312041795 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 16 	|		 50 	  | 0.37196305200563984 	| 0.1976293121586563 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 17 	|		 50 	  | 0.33179937555074446 	| 0.17025422056732875 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 18 	|		 50 	  | 0.2964955654430099 	| 0.10550144415198881 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 19 	|		 50 	  | 0.2653853610580654 	| 0.10099605577726534 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 20 	|		 50 	  | 0.23787832624702787 	| 0.0615044681526391 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 21 	|		 50 	  | 0.21346879486011971 	| 0.0663876908146368 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 22 	|		 50 	  | 52.05092182483618 	| 0.039706820987376545 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 23 	|		 50 	  | 0.1723030889790209 	| 0.03975478632607521 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 24 	|		 50 	  | 0.1548873036888665 	| 0.03249184422788165 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 25 	|		 50 	  | 0.13922913864476527 	| 0.02549532098364926 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 26 	|		 50 	  | 0.12511452678430146 	| 0.023216171265310948 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 27 	|		 50 	  | 0.11236183189132021 	| 0.01932823997301103 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 28 	|		 50 	  | 0.10081620504283251 	| 0.014144995246617942 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 29 	|		 50 	  | 52.05092182483618 	| 0.014045440767551653 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 30 	|		 50 	  | 0.0808340201189992 	| 0.012778452254444517 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 31 	|		 50 	  | 0.07218453456445673 	| 0.009769376483636627 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 32 	|		 50 	  | 0.06431075447662238 	| 0.010138510849931226 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 33 	|		 50 	  | 0.05713783134521577 	| 0.008334069555087975 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 34 	|		 50 	  | 0.05060018583557735 	| 0.007132444057696308 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 35 	|		 50 	  | 0.044640131498539404 	| 0.006138311164628263 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 36 	|		 50 	  | 52.05092182483618 	| 0.004360013866612444 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 37 	|		 50 	  | 0.03425485299098341 	| 0.003496989674619755 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 38 	|		 50 	  | 0.029744357389375864 	| 0.0032172838881208143 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 39 	|		 50 	  | 0.025639442563459625 	| 0.003443547572936634 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 40 	|		 50 	  | 0.021908070228704446 	| 0.0033346388775452596 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 41 	|		 50 	  | 0.018521486847106416 	| 0.003394937461342451 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 42 	|		 50 	  | 0.015453814524192921 	| 0.0030461055399100267 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 43 	|		 50 	  | 52.05092182483618 	| 0.0029147127745372536 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 44 	|		 50 	  | 0.010184020668106086 	| 0.0023763884357164144 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 45 	|		 50 	  | 0.00794161366192725 	| 0.002201794418471348 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 46 	|		 50 	  | 0.005937064809444337 	| 0.0018950348287201102 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 47 	|		 50 	  | 0.0041545086836265455 	| 0.0014349566367322097 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 48 	|		 50 	  | 0.0025794612982679155 	| 0.0014207443202494119 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 49 	|		 50 	  | 0.0011986730483783958 	| 0.00152408920314695 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 50 	|		 50 	  | 90.66846312041795 	| 0.001234465566704479 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 51 	|		 50 	  | 0.0010292667730311678 	| 0.0013530350289636672 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 52 	|		 50 	  | 0.0019066873242366 	| 0.0012736302753424411 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 53 	|		 50 	  | 0.002649329171077852 	| 0.0009503522893030691 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 54 	|		 50 	  | 0.0032723456994574462 	| 0.0011408536883474873 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 55 	|		 50 	  | 0.0037892092035747282 	| 0.0007929412564369187 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 56 	|		 50 	  | 0.0042119130122557635 	| 0.0008963337682987849 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 57 	|		 50 	  | 52.05092182483618 	| 0.0007744508647156145 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 58 	|		 50 	  | 0.004816451161019586 	| 0.0007927849699553846 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 59 	|		 50 	  | 0.005016347582483149 	| 0.0007069401736528036 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 60 	|		 50 	  | 0.005158458269448829 	| 0.0006783003360935069 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 61 	|		 50 	  | 0.005249606399189588 	| 0.0006055040552315205 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 62 	|		 50 	  | 0.005295905793133215 	| 0.0004869013494390728 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 63 	|		 50 	  | 0.005302839375559643 	| 0.0005836022460701251 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 64 	|		 50 	  | 52.05092182483618 	| 0.00036027975494423714 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 65 	|		 50 	  | 0.005217792047375269 	| 0.0005365497144644849 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 66 	|		 50 	  | 0.005134203427729744 	| 0.0003181618261667296 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 67 	|		 50 	  | 0.005028134595164602 	| 0.0004494713267968464 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 68 	|		 50 	  | 0.004902799678035308 	| 0.00026239805673133887 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 69 	|		 50 	  | 0.004761091808092033 	| 0.00036842184188223825 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 70 	|		 50 	  | 0.004605616119448541 	| 0.00028134677466251645 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 71 	|		 50 	  | 52.05092182483618 	| 0.00023178115434951962 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 72 	|		 50 	  | 0.004262514554653762 	| 0.0002912203533069757 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 73 	|		 50 	  | 0.0040789071346409855 	| 0.00010039912242376658 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 74 	|		 50 	  | 0.003889612833660294 	| 0.000304898643002538 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 75 	|		 50 	  | 0.0036961776537793867 	| 0.00015231931197234871 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 76 	|		 50 	  | 0.003499994178724819 	| 0.00028519198812970714 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 77 	|		 50 	  | 0.0033023164263852323 	| 0.00017284946203233176 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 78 	|		 50 	  | 52.05092182483618 	| 0.00023337499337516832 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 79 	|		 50 	  | 0.0029068799202889295 	| 9.62007094784667e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 80 	|		 50 	  | 0.002711049616806349 	| 0.00016516673405053695 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 81 	|		 50 	  | 0.002517602347694492 	| 0.00015226958297454019 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 82 	|		 50 	  | 0.0023272740237700873 	| 0.00011840135456164802 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 83 	|		 50 	  | 0.002140724238557823 	| 0.00018171044146875204 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 84 	|		 50 	  | 0.001958543332790441 	| 9.985342521900975e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 85 	|		 50 	  | 52.05092182483618 	| 0.0001748051409369289 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 86 	|		 50 	  | 0.0016093410175983536 	| 0.00010989028272589962 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 87 	|		 50 	  | 0.0014432085639839443 	| 0.00016547499152075318 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 88 	|		 50 	  | 0.0012832328499428058 	| 0.0001049641506432053 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 89 	|		 50 	  | 0.0011297424609040263 	| 0.00013695077499065178 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 90 	|		 50 	  | 0.000983027025682759 	| 0.00011005232477634408 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 91 	|		 50 	  | 0.0008433407435006757 	| 0.0001221192918672287 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 92 	|		 50 	  | 52.05092182483618 	| 0.00012376055866347713 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 93 	|		 50 	  | 0.0005859142310384868 	| 0.00010632818559663804 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 94 	|		 50 	  | 0.0004685326488527153 	| 0.00011028602645701824 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 95 	|		 50 	  | 0.00035890256904735907 	| 8.626580827542085e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 96 	|		 50 	  | 0.00025714364838336223 	| 0.00010742389003093322 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 97 	|		 50 	  | 0.00016335546357026942 	| 7.914796001795565e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 98 	|		 50 	  | 7.761934026007111e-05 	| 0.00010256230226168839 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 99 	|		 50 	  | 90.66846312041795 	| 8.115591414536993e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 100 	|		 50 	  | 6.955549937970318e-05 	| 8.556996878805734e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 101 	|		 50 	  | 0.0001315077529966402 	| 8.632968934563223e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 102 	|		 50 	  | 0.00018638896000311433 	| 6.732485453753156e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 103 	|		 50 	  | 0.00023469845382351195 	| 7.308808516093279e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 104 	|		 50 	  | 0.0002769049273751989 	| 6.922352794536124e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 105 	|		 50 	  | 0.00031344848596859265 	| 6.28579027179832e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 106 	|		 50 	  | 52.05092182483618 	| 6.62854607456076e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 107 	|		 50 	  | 0.00037117557025112546 	| 6.967080140407589e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 108 	|		 50 	  | 0.00039311272607278624 	| 6.0773847232908906e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 109 	|		 50 	  | 0.0004108973519691972 	| 6.693062134566219e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 110 	|		 50 	  | 0.0004248523694627693 	| 6.129143954058947e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 111 	|		 50 	  | 0.00043528157058858596 	| 5.616693067622691e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 112 	|		 50 	  | 0.00044247082175274954 	| 4.914953074397488e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 113 	|		 50 	  | 52.05092182483618 	| 4.0249793326285754e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 114 	|		 50 	  | 0.00044818991779038697 	| 3.158438071926284e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 115 	|		 50 	  | 0.00044721152201532277 	| 3.7775263228567724e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 116 	|		 50 	  | 0.00044397856075306663 	| 4.238060328010107e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 117 	|		 50 	  | 0.0004387025417145196 	| 4.604330090174358e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 118 	|		 50 	  | 0.00043158269050991294 	| 4.717463512271536e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 119 	|		 50 	  | 0.00042280668318994685 	| 4.4068445865796946e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 120 	|		 50 	  | 45.98989450169442 	| 4.552367263865875e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 121 	|		 50 	  | 0.0004009832148028636 	| 3.893659182718778e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 122 	|		 50 	  | 0.00038825929021868433 	| 3.836258606870757e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 123 	|		 50 	  | 0.00037452744021493345 	| 3.573515305665964e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 124 	|		 50 	  | 0.00035992700236420205 	| 3.0714344875004684e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 125 	|		 50 	  | 0.00034458925830449516 	| 3.061631761713812e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 126 	|		 50 	  | 0.0003286378941993462 	| 3.5183638146918383e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 127 	|		 50 	  | 52.05092182483618 	| 2.9637417292782686e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 128 	|		 50 	  | 0.0002953536372558574 	| 3.1953087796132706e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 129 	|		 50 	  | 0.0002782338928284389 	| 3.30879657126637e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 130 	|		 50 	  | 0.00026092756263551564 	| 2.3374984143842426e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 131 	|		 50 	  | 0.0002435263240840868 	| 3.203392032125052e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 132 	|		 50 	  | 0.0002261164838444074 	| 2.248208966681986e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 133 	|		 50 	  | 0.00020877927534002083 	| 2.7074902710921833e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 134 	|		 50 	  | 52.05092182483618 	| 2.4176671332476474e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 135 	|		 50 	  | 0.00017462397519807382 	| 2.7046277898179483e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 136 	|		 50 	  | 0.0001579454131501734 	| 2.4277908219794142e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 137 	|		 50 	  | 0.00014161902245746205 	| 2.3276978945219184e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 138 	|		 50 	  | 0.00012570454323679314 	| 2.2769957022994447e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 139 	|		 50 	  | 0.00011025809187970026 	| 1.817282676341847e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 140 	|		 50 	  | 9.533235565584164e-05 	| 2.389938865787755e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 141 	|		 50 	  | 52.05092182483618 	| 1.523219969712386e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 142 	|		 50 	  | 6.723772811767503e-05 	| 2.3191223379459558e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 143 	|		 50 	  | 5.415867455837997e-05 	| 1.227405475390242e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 144 	|		 50 	  | 4.178033036339457e-05 	| 2.0867041262029318e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 145 	|		 50 	  | 3.0140804298639523e-05 	| 1.2508311485248669e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 146 	|		 50 	  | 1.9275738338819792e-05 	| 1.6975933883500716e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 147 	|		 50 	  | 1.6478447903978122e-05 	| 1.393872771426885e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 148 	|		 50 	  | 90.66846312041795 	| 1.2830985653522475e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 149 	|		 50 	  | 1.648068344195508e-05 	| 1.5800666021803522e-05 		 |
# -----------------------------------------------------------------------------------------------------------
# |	 150 	|		 50 	  | 1.6481774835597207e-05 	| 1.3028920804458721e-05 		 |
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Графики распределения абсолютной погрешности на интервале интерполирования для кубического сплайна $S_{3,2}$ и полинома Ньютона по равноотстоящим узлам и по «оптимальным узлам» при некоторых значениях $n$
